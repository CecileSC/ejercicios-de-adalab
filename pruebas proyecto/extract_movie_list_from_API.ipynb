# %%
import requests
import pandas as pd

# %%
# Key Bea = 30f6c00168msh1b42af1260e2970p1cb797jsn775f4f1bf53e
# Key Bea2 = 7da7d1d9f2mshd70f16dedff8827p11e4cejsnc105329a0d9c
# Key Ceci = dab5a0167dmsh4ab1543f0fd8e0ap1d9b21jsnd66b36d85213
# Key Carla = f600d33197mshe21c869c19877bbp16c957jsn8dea9e68b50b

def api_call(url):
    headers = {
        "x-rapidapi-key": "dab5a0167dmsh4ab1543f0fd8e0ap1d9b21jsnd66b36d85213", 
        "x-rapidapi-host": "moviesdatabase.p.rapidapi.com"
    }

    call = requests.get(url, headers=headers)
    print(f"The API call gave us a response of type: {call.status_code}")
    if call.status_code != 200:
        print(f"The reason for the failure is: {call.reason}")
        return None
    else:
        return call.json()

def movies_by_genre(genre_list):
    movies_list = []

    for genre in genre_list:
        for i in range(r_ini, r_fin): # 2, 3 / 3, 4 / ...
            url_movies = f'https://moviesdatabase.p.rapidapi.com/titles?genre={genre}&startYear=2010&titleType=movie&page={i}&endYear=2024&limit=50'
            response_dict_movies = api_call(url_movies)

            if response_dict_movies and "results" in response_dict_movies:
                for result in response_dict_movies["results"]:
                    result["genre"] = genre
                movies_list.extend(response_dict_movies["results"])

            print(f"\n ITERACION {genre} {i} \n")
            if response_dict_movies:
                print(f"\nThe answer for movies is type: {type(response_dict_movies)}, the length is: {len(response_dict_movies)} and the keys are: {response_dict_movies.keys()}\n")
                print(response_dict_movies)

    return movies_list

def shorts_by_genre(genre_list):
    shorts_list = []

    for genre in genre_list:
        for i in range(r_ini, r_fin): 
            url_short = f'https://moviesdatabase.p.rapidapi.com/titles?genre={genre}&startYear=2010&titleType=short&page={i}&endYear=2024&limit=50'
            response_dict_shorts = api_call(url_short)

            if response_dict_shorts and "results" in response_dict_shorts:
                for result in response_dict_shorts["results"]:
                    result["genre"] = genre
                shorts_list.extend(response_dict_shorts["results"])

            print(f"\n ITERACION {genre} {i} \n")
            if response_dict_shorts:
                print(f"\nThe answer for shorts is type: {type(response_dict_shorts)}, the length is: {len(response_dict_shorts)} and the keys are: {response_dict_shorts.keys()}\n")
                print(response_dict_shorts)

    return shorts_list

def process_results(results_list):
    full_list = []
    for item in results_list:
        item_data = []
        item_data.append(item["titleType"].get("text"))
        item_data.append(item["titleText"].get("text"))
        item_data.append(item["releaseYear"].get("year"))
        try:
            item_data.append(item["releaseDate"].get("month"))
        except:
            item_data.append("none")
        item_data.append(item["id"])
        item_data.append(item["genre"])
        
        full_list.append(tuple(item_data))
    return full_list

def combine_results(genre_list):
    movies_list = movies_by_genre(genre_list)
    shorts_list = shorts_by_genre(genre_list)
    
    combined_list = movies_list + shorts_list
    processed_list = process_results(combined_list)
    
    return processed_list

r_ini = 30
r_fin = r_ini + 1
# call to main function
genre_list = ["Drama"] # Genres: "Action", "Drama", "Comedy"
combined_results = combine_results(genre_list)

# Create DataFrame
list_headers = ["type", "name", "release_year", "release_month", "id_imdb", "genre"]
df_full_movie_list = pd.DataFrame(combined_results, columns=list_headers)

# Set 'id_imdb' as index
df_full_movie_list.set_index('id_imdb', inplace=True)

# Show DataFrame
df_full_movie_list
# Out:
# The API call gave us a response of type: 200
#
#  ITERACION Drama 30
#
#
# The answer for movies is type: <class 'dict'>, the length is: 4 and the keys are: dict_keys(['page', 'next', 'entries', 'results'])
#
# {'page': '30', 'next': '/titles?titleType=movie&genre=Drama&page=31&limit=50&startYear=2010&endYear=2024', 'entries': 50, 'results': [{'_id': '66635a076c95d57ba93f4061', 'id': 'tt32551664', 'primaryImage': None, 'titleType': {'displayableProperty': {'value': {'plainText': '', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Los Capítulos Perdidos', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Los Capítulos Perdidos', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 26, 'month': 6, 'year': 2024, '__typename': 'ReleaseDate'}, 'genre': 'Drama'}, {'_id': '6665f88d6cc93870c8609073', 'id': 'tt32553390', 'primaryImage': {'id': 'rm1053455873', 'width': 1080, 'height': 1725, 'url': 'https://m.media-amazon.com/images/M/MV5BZDYyZDM1OTItNWU2Ni00MDIyLWExN2EtNjY2YzQ4Y2UzYWFiXkEyXkFqcGc@._V1_.jpg', 'caption': {'plainText': 'Francis Ng, Shengdi Wang, Janine Chun-Ning Chang, and Chuan-jun Wang in Mo Sha (2024)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': '', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Mo Sha', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Mo Sha', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 3, 'month': 7, 'year': 2024, '__typename': 'ReleaseDate'}, 'genre': 'Drama'}, {'_id': '6665f8b2bbb950c8ca6090b1', 'id': 'tt32553611', 'primaryImage': {'id': 'rm1242263809', 'width': 2953, 'height': 4134, 'url': 'https://m.media-amazon.com/images/M/MV5BZThlMDM5MjUtNmNhYi00MTc2LWFjMDgtYTIzOTRiMzA0MzQ1XkEyXkFqcGc@._V1_.jpg', 'caption': {'plainText': 'Sve si u pravu (2024)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': '', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Sve si u pravu', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Sve si u pravu', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 10, 'month': 10, 'year': 2024, '__typename': 'ReleaseDate'}, 'genre': 'Drama'}, {'_id': '6665f8bcbbb950c8ca6090cb', 'id': 'tt32553734', 'primaryImage': {'id': 'rm995520513', 'width': 900, 'height': 1285, 'url': 'https://m.media-amazon.com/images/M/MV5BYjg0ZjhkZjEtM2VjZS00OTYyLWJlYWItMGY2Y2E3NjhkMWRkXkEyXkFqcGc@._V1_.jpg', 'caption': {'plainText': 'Terrence France Jr., Damion Sirdeezel France, and Malika M. Jones in The Queen of Diamonds (2024)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': '', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'The Queen of Diamonds', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'The Queen of Diamonds', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': 4, 'year': 2024, '__typename': 'Rel ...
# The API call gave us a response of type: 200
#
#  ITERACION Drama 30
#
#
# The answer for shorts is type: <class 'dict'>, the length is: 4 and the keys are: dict_keys(['page', 'next', 'entries', 'results'])
#
# {'page': '30', 'next': '/titles?titleType=short&genre=Drama&page=31&limit=50&startYear=2010&endYear=2024', 'entries': 50, 'results': [{'_id': '65f427d4f8846dc3b3b627c2', 'id': 'tt31066444', 'primaryImage': None, 'titleType': {'displayableProperty': {'value': {'plainText': 'Short', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Loving Strangers in A Bar', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Loving Strangers in A Bar', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 27, 'month': 1, 'year': 2024, '__typename': 'ReleaseDate'}, 'genre': 'Drama'}, {'_id': '65f427d5386b5f8c6bb627d8', 'id': 'tt31066451', 'primaryImage': {'id': 'rm2871610625', 'width': 2025, 'height': 3000, 'url': 'https://m.media-amazon.com/images/M/MV5BOTMyMjI4MzctNDZkNy00MzFmLWExZWUtZmUwZTRhZThhZjY3XkEyXkFqcGdeQXVyMTQ2MjA4NDM4._V1_.jpg', 'caption': {'plainText': 'Red Plaid (2024)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': 'Short', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Red Plaid', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Red Plaid', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 1, 'month': 3, 'year': 2024, '__typename': 'ReleaseDate'}, 'genre': 'Drama'}, {'_id': '65f427f5386b5f8c6bb628a9', 'id': 'tt31124727', 'primaryImage': {'id': 'rm4129899009', 'width': 3105, 'height': 4600, 'url': 'https://m.media-amazon.com/images/M/MV5BZjllZDIyNDMtYmU0MC00Mzc2LTlhMzEtM2VlNzgwMjI0NTI1XkEyXkFqcGdeQXVyMTI0MDQxMjU0._V1_.jpg', 'caption': {'plainText': 'Shadow of Star (2024)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': 'Short', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Shadow of Star', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Shadow of Star', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 2, 'month': 2, 'year': 2024, '__typename': 'ReleaseDate'}, 'genre': 'Drama'}, {'_id': '65f427fdf8846dc3b3b628d6', 'id': 'tt31182720', 'primaryImage': {'id': 'rm3980411649', 'width': 1240, 'height': 1753, 'url': 'https://m.media-amazon.com/images/M/MV5BM2I4ZjhiNTQtZjg0Zi00YzIyLWIwMTktM2FlNjgyOGZiZWEyXkEyXkFqcGdeQXVyOTMzNzkyNjU@._V1_.jpg', 'caption': {'plainText': 'The Lost Love (2024)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': 'Short', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'The Lost Love', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'The Lost Love', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 29, 'month': 1, 'year': 2024, '__typename': 'ReleaseDate'}, 'genre': 'Drama'}, {'_id': '65f4280af8846dc3b3b62939', 'id': 'tt31236543 ...
#              type                    name  release_year release_month  genre
# id_imdb
# tt32551664  Movie  Los Capítulos Perdidos          2024             6  Drama
# tt32553390  Movie                  Mo Sha          2024             7  Drama
# tt32553611  Movie          Sve si u pravu          2024            10  Drama
# tt32553734  Movie   The Queen of Diamonds          2024             4  Drama
# tt32557085  Movie               Face Deep          2024             5  Drama
# ...           ...                     ...           ...           ...    ...
# tt31556175  Short              The Fridge          2024             8  Drama
# tt31556206  Short               Heartland          2024             3  Drama
# tt31556341  Short          One Last Dance          2024             5  Drama
# tt31556362  Short            Undying Love          2024             3  Drama
# tt31556720  Short             Open Casket          2024          none  Drama
#
# [100 rows x 5 columns]

# %%
df_full_movie_list.to_csv("api_drama/list_drama_range_30_31_API.csv")
